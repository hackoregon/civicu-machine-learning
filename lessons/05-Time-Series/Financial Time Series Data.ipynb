# %%
from IPython.display import display, HTML
import pandas as pd
import seaborn as sns
pd.set_option('display.max_rows', 6)

# %%
# pandas-datareader package has a DataReader class for Yahoo finance, Google finance, etc

import pandas_datareader.data as web
# from datetime import datetime

df = pd.DataFrame()
symbols = 'GOOG IBM GE TSLA AAPL'.split()
for symbol in symbols:
    df_onesym = web.DataReader(symbol, 'yahoo', '2010-07-17', '2017-10-08')
    for name in df_onesym:
        newname = symbol.lower() + '_' + name.replace(' ', '_').lower()
        df[newname] = df_onesym[name]
df.to_csv('../shared-resources/time_series/time-series.csv')
df = df.fillna(method='ffill')
df = df.reindex()

# %%
type(df.index)  # dtype object
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df.index.name = df.index.name.lower().replace(' ', '_')
df.index = pd.to_datetime(df.index)
df = df.fillna(method='ffill')
df = df.reindex()
df.to_csv('../shared-resources/time_series/time-series.csv')

# %%
df
# Out:
#              goog_open   goog_high    goog_low  goog_close  goog_adj_close  \
# date
# 2010-07-19  229.015472  233.307556  227.281754  231.583771      231.583771
# 2010-07-20  229.025406  239.934464  228.811798  239.238983      239.238983
# 2010-07-21  240.436188  241.280701  236.178879  237.207199      237.207199
# ...                ...         ...         ...         ...             ...
# 2017-10-05  955.489990  970.909973  955.179993  969.960022      969.960022
# 2017-10-06  966.700012  979.460022  963.359985  978.890015      978.890015
# 2017-10-09  980.000000  985.424988  976.109985  977.000000      977.000000
#
#             goog_volume    ibm_open    ibm_high     ibm_low   ibm_close  \
# date
# 2010-07-19      9159800  128.669998  130.380005  128.369995  129.789993
# 2010-07-20      8161600  122.970001  126.559998  122.930000  126.550003
# 2010-07-21      6601800  126.440002  126.500000  124.620003  125.269997
# ...                 ...         ...         ...         ...         ...
# 2017-10-05      1213800  146.679993  147.539993  146.479996  146.720001
# 2017-10-06      1173900  146.639999  146.850006  146.320007  146.479996
# 2017-10-09       891400  146.500000  147.789993  146.350006  147.389999
#
#                ...         tsla_low  tsla_close  tsla_adj_close  tsla_volume  \
# date           ...
# 2010-07-19     ...        20.920000   21.910000       21.910000      2486500
# 2010-07-20     ...        20.049999   20.299999       20.299999      1825300
# 2010-07-21     ...        19.500000   20.219999       20.219999      1252500
# ...            ...              ...         ...             ...          ...
# 2017-10-05     ...       351.350006  355.329987      355.329987      4171700
# 2017-10-06     ...       352.250000  356.880005      356.880005      4297500
# 2017-10-09     ...       342.670013  342.940002      342.940002      7493700
#
#              aapl_open   aapl_high    aapl_low  aapl_close  aapl_adj_close  \
# date
# 2010-07-19   35.697144   35.697144   34.228573   35.082859       31.562510
# 2010-07-20   34.700001   36.128571   34.287144   35.984287       32.373478
# 2010-07-21   37.869999   37.878571   36.285713   36.320000       32.675503
# ...                ...         ...         ...         ...             ...
# 2017-10-05  154.179993  155.440002  154.050003  155.389999      155.389999
# 2017-10-06  154.970001  155.490005  154.559998  155.300003      155.300003
# 2017-10-09  155.809998  156.729996  155.490005  155.839996      155.839996
#
#             aapl_volume
# date
# 2010-07-19    256119500
# 2010-07-20    268737700
# 2010-07-21    296417800
# ...                 ...
# 2017-10-05     21283800
# 2017-10-06     17407600
# 2017-10-09     16262900
#
# [1821 rows x 30 columns]

# %%
df.describe()
# Out:
#          goog_open    goog_high     goog_low   goog_close  goog_adj_close  \
# count  1821.000000  1821.000000  1821.000000  1821.000000     1821.000000
# mean    519.550338   523.482682   515.186408   519.477521      519.477521
# std     207.677700   208.879226   206.270699   207.715681      207.715681
# ...            ...          ...          ...          ...             ...
# 50%     525.749146   529.729614   521.120605   525.587646      525.587646
# 75%     702.179993   709.750000   694.049988   701.789978      701.789978
# max     984.500000   988.250000   977.200012   983.679993      983.679993
#
#         goog_volume     ibm_open     ibm_high      ibm_low    ibm_close  \
# count  1.821000e+03  1821.000000  1821.000000  1821.000000  1821.000000
# mean   3.558634e+06   170.710972   171.910154   169.622109   170.799835
# std    2.721922e+06    21.983505    22.069507    21.916405    21.974165
# ...             ...          ...          ...          ...          ...
# 50%    2.995200e+06   169.630005   171.039993   168.460007   170.050003
# 75%    4.664900e+06   189.850006   190.889999   188.520004   189.830002
# max    2.984230e+07   215.380005   215.899994   214.300003   215.800003
#
#            ...          tsla_low   tsla_close  tsla_adj_close   tsla_volume  \
# count      ...       1821.000000  1821.000000     1821.000000  1.821000e+03
# mean       ...        146.279121   148.923515      148.923515  4.450834e+06
# std        ...        103.925762   105.491464      105.491464  4.254706e+06
# ...        ...               ...          ...             ...           ...
# 50%        ...        180.419998   183.559998      183.559998  3.472400e+06
# 75%        ...        226.550003   230.029999      230.029999  5.977400e+06
# max        ...        379.350006   385.000000      385.000000  3.716390e+07
#
#          aapl_open    aapl_high     aapl_low   aapl_close  aapl_adj_close  \
# count  1821.000000  1821.000000  1821.000000  1821.000000     1821.000000
# mean     89.833707    90.590784    89.011243    89.822102       85.151329
# std      31.444340    31.625268    31.239522    31.445372       32.501687
# ...            ...          ...          ...          ...             ...
# 50%      88.571426    89.285713    87.894287    88.675713       80.358292
# 75%     112.580002   113.769997   111.550003   112.650002      109.149773
# max     164.800003   164.940002   163.630005   164.050003      164.050003
#
#         aapl_volume
# count  1.821000e+03
# mean   8.117907e+07
# std    5.503886e+07
# ...             ...
# 50%    6.846000e+07
# 75%    1.070678e+08
# max    4.702495e+08
#
# [8 rows x 30 columns]

# %%
df = pd.read_csv('../shared-resources/time_series/time-series.csv', index_col=0, header=0, parse_dates=True)
type(df.index)
df.index.isnull().sum()
# Out:
# 0

# %%
df = pd.read_csv('../shared-resources/time_series/time-series.csv', index_col=0, header=0, parse_dates=True)
btc = pd.read_csv('../shared-resources/time_series/coindesk-bpi-USD-ohlc_data-2010-06-30_2017-10-08.csv',
                  index_col=0, header=0, parse_dates=True)
btc.head()
btc.index = btc.index.astype(df.index.dtype)
for col in btc.columns:
    df[col.replace(' ', '_').lower()] = btc[col]
df.to_csv('../shared-resources/time_series/time-series2.csv')
df.head()
# Out:
#              goog_open   goog_high    goog_low  goog_close  goog_adj_close  \
# date
# 2010-07-19  229.015472  233.307556  227.281754  231.583771      231.583771
# 2010-07-20  229.025406  239.934464  228.811798  239.238983      239.238983
# 2010-07-21  240.436188  241.280701  236.178879  237.207199      237.207199
# 2010-07-22  240.053680  242.910110  239.681107  240.838577      240.838577
# 2010-07-23  238.831635  243.709900  238.454086  243.446609      243.446609
#
#             goog_volume    ibm_open    ibm_high     ibm_low   ibm_close  \
# date
# 2010-07-19      9159800  128.669998  130.380005  128.369995  129.789993
# 2010-07-20      8161600  122.970001  126.559998  122.930000  126.550003
# 2010-07-21      6601800  126.440002  126.500000  124.620003  125.269997
# 2010-07-22      4323200  126.320000  127.779999  126.050003  127.470001
# 2010-07-23      4558200  127.300003  128.800003  127.000000  128.380005
#
#             ...    aapl_open  aapl_high   aapl_low  aapl_close  \
# date        ...
# 2010-07-19  ...    35.697144  35.697144  34.228573   35.082859
# 2010-07-20  ...    34.700001  36.128571  34.287144   35.984287
# 2010-07-21  ...    37.869999  37.878571  36.285713   36.320000
# 2010-07-22  ...    36.811428  37.142857  36.472858   37.002857
# 2010-07-23  ...    36.727142  37.197144  36.611427   37.134285
#
#             aapl_adj_close  aapl_volume  open  high   low  close
# date
# 2010-07-19       31.562510    256119500  0.09  0.09  0.08   0.08
# 2010-07-20       32.373478    268737700  0.08  0.08  0.07   0.07
# 2010-07-21       32.675503    296417800  0.07  0.08  0.07   0.08
# 2010-07-22       33.289845    161329700  0.08  0.08  0.05   0.05
# 2010-07-23       33.408085    133347200  0.05  0.07  0.05   0.06
#
# [5 rows x 34 columns]

# %%
df.describe()
# Out:
#          goog_open    goog_high     goog_low   goog_close  goog_adj_close  \
# count  1821.000000  1821.000000  1821.000000  1821.000000     1821.000000
# mean    519.550338   523.482682   515.186408   519.477521      519.477521
# std     207.677700   208.879226   206.270699   207.715681      207.715681
# ...            ...          ...          ...          ...             ...
# 50%     525.749146   529.729614   521.120605   525.587646      525.587646
# 75%     702.179993   709.750000   694.049988   701.789978      701.789978
# max     984.500000   988.250000   977.200012   983.679993      983.679993
#
#         goog_volume     ibm_open     ibm_high      ibm_low    ibm_close  \
# count  1.821000e+03  1821.000000  1821.000000  1821.000000  1821.000000
# mean   3.558634e+06   170.710972   171.910154   169.622109   170.799835
# std    2.721922e+06    21.983505    22.069507    21.916405    21.974165
# ...             ...          ...          ...          ...          ...
# 50%    2.995200e+06   169.630005   171.039993   168.460007   170.050003
# 75%    4.664900e+06   189.850006   190.889999   188.520004   189.830002
# max    2.984230e+07   215.380005   215.899994   214.300003   215.800003
#
#           ...         aapl_open    aapl_high     aapl_low   aapl_close  \
# count     ...       1821.000000  1821.000000  1821.000000  1821.000000
# mean      ...         89.833707    90.590784    89.011243    89.822102
# std       ...         31.444340    31.625268    31.239522    31.445372
# ...       ...               ...          ...          ...          ...
# 50%       ...         88.571426    89.285713    87.894287    88.675713
# 75%       ...        112.580002   113.769997   111.550003   112.650002
# max       ...        164.800003   164.940002   163.630005   164.050003
#
#        aapl_adj_close   aapl_volume         open         high          low  \
# count     1821.000000  1.821000e+03  1821.000000  1821.000000  1821.000000
# mean        85.151329  8.117907e+07   454.056678   468.253558   440.055887
# std         32.501687  5.503886e+07   770.860218   798.702954   744.255391
# ...               ...           ...          ...          ...          ...
# 50%         80.358292  6.846000e+07   236.210000   239.490000   232.130000
# 75%        109.149773  1.070678e+08   576.000000   583.990000   560.350000
# max        164.050003  4.702495e+08  4764.870000  4950.720000  4726.740000
#
#              close
# count  1821.000000
# mean    455.949357
# std     775.717112
# ...            ...
# 50%     236.550000
# 75%     575.070000
# max    4950.720000
#
# [8 rows x 34 columns]

# %% [markdown]
# ## Your Turn
#
# 1. load the time series of bitcoin prices from the ../shared-resources/ directory
# 2. make sure there aren't any "Unknown" columns of integers in your
# 2. make sure the index has an appropriate type for a *time series*
# 3. add a column to this time-series.csv file for bitcoin
# 3. save it to 'time-series-with-bitcoin.csv'
#
# ## BONUS
#
# 1. find a stock/commodity/index you're interested in: '../shared-resources/time_series/secwiki_tickers.csv'
# 2. use yahoo or google finance to download it's data
# 3. Add columns for it to your time series DataFrame
# 4. save it to a csv for use later in class
