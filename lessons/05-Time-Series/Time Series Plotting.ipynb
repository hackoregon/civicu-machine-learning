# %%
from IPython.display import display, HTML
import pandas as pd
import seaborn as sns
pd.set_option('display.max_rows', 6)
pd.set_option('display.max_columns', 500)
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML(open("../shared-resources/jupyter.css", "r").read()))
import mpld3
# Out:
# <style>
#     .container {
#         width: 99%;
#     }
#     div.cell{
#         width: 99%;
#         margin-left: 1%;
#         margin-right: auto;
#     }
#     div.cell.selected {
#         border-left-width: 1px;
#     }
# </style>

# %%
df = pd.read_csv('../shared-resources/time_series/time-series.csv', index_col=0, header=0, parse_dates=True)
df
# Out:
#              goog_open   goog_high    goog_low  goog_close  goog_adj_close  \
# date
# 2010-07-19  229.015472  233.307556  227.281754  231.583771      231.583771
# 2010-07-20  229.025406  239.934464  228.811798  239.238983      239.238983
# 2010-07-21  240.436188  241.280701  236.178879  237.207199      237.207199
# ...                ...         ...         ...         ...             ...
# 2017-10-04  957.000000  960.390015  950.690002  951.679993      951.679993
# 2017-10-05  955.489990  970.909973  955.179993  969.960022      969.960022
# 2017-10-06  966.700012  979.460022  963.359985  978.890015      978.890015
#
#             goog_volume    ibm_open    ibm_high     ibm_low   ibm_close  \
# date
# 2010-07-19      9159800  128.669998  130.380005  128.369995  129.789993
# 2010-07-20      8161600  122.970001  126.559998  122.930000  126.550003
# 2010-07-21      6601800  126.440002  126.500000  124.620003  125.269997
# ...                 ...         ...         ...         ...         ...
# 2017-10-04       952400  147.000000  147.020004  146.110001  146.479996
# 2017-10-05      1213800  146.679993  147.539993  146.479996  146.720001
# 2017-10-06      1145200  146.639999  146.850006  146.320007  146.479996
#
#             ibm_adj_close  ibm_volume    ge_open    ge_high     ge_low  \
# date
# 2010-07-19     108.010506     8388600  14.640000  14.740000  14.470000
# 2010-07-20     105.314224    16337400  14.360000  15.010000  14.360000
# 2010-07-21     104.248978     8615500  15.110000  15.200000  14.640000
# ...                   ...         ...        ...        ...        ...
# 2017-10-04     146.479996     2244400  24.879999  24.889999  24.430000
# 2017-10-05     146.720001     2686500  24.389999  24.570000  24.150000
# 2017-10-06     146.479996     2248500  24.410000  24.540001  24.129999
#
#              ge_close  ge_adj_close  ge_volume   tsla_open   tsla_high  \
# date
# 2010-07-19  14.620000     11.455877   49073000   21.370001   22.250000
# 2010-07-20  14.940000     11.706622   67279400   21.850000   21.850000
# 2010-07-21  14.840000     11.628263   65021900   20.660000   20.900000
# ...               ...           ...        ...         ...         ...
# 2017-10-04  24.480000     24.480000   32067600  351.250000  358.619995
# 2017-10-05  24.540001     24.540001   34758900  356.000000  357.440002
# 2017-10-06  24.389999     24.389999   39735400  353.100006  360.100006
#
#               tsla_low  tsla_close  tsla_adj_close  tsla_volume   aapl_open  \
# date
# 2010-07-19   20.920000   21.910000       21.910000      2486500   35.697144
# 2010-07-20   20.049999   20.299999       20.299999      1825300   34.700001
# 2010-07-21   19.500000   20.219999       20.219999      1252500   37.869999
# ...                ...         ...             ...          ...         ...
# 2017-10-04  349.600006  355.010010      355.010010      8163500  153.630005
# 2017-10-05  351.350006  355.329987      355.329987      4171700  154.179993
# 2017-10-06  352.250000  356.880005      356.880005      4215700  154.970001
#
#              aapl_high    aapl_low  aapl_close  aapl_adj_close  aapl_volume
# date
# 2010-07-19   35.697144   34.228573   35.082859       31.562510    256119500
# 2010-07-20   36.128571   34.287144   35.984287       32.373478    268737700
# 2010-07-21   37.878571   36.285713   36.320000       32.675503    296417800
# ...                ...         ...         ...             ...          ...
# 2017-10-04  153.860001  152.460007  153.479996      153.479996     20163800
# 2017-10-05  155.440002  154.050003  155.389999      155.389999     21283800
# 2017-10-06  155.490005  154.559998  155.300003      155.300003     16478900
#
# [1820 rows x 30 columns]

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
ax = df[[c for c in df.columns if c.startswith('tsla')]].plot(figsize=(16, 6))

# %%
# all quantities in relative change since 2011/07/10 
start_values = df.iloc[0]
df = df / start_values

# %%
ax = df[[c for c in df.columns if c.startswith('tsla')]].plot(logy=True, figsize=(16, 6))

# %%
mpld3.display(ax.figure)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el48941403490389756881821244251"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el48941403490389756881821244251", {"height": 432.0, "plugins": [{"type": "reset"}, {"button": true, "enabled": false, "type": "zoom"}, {"button": true, "enabled": false, "type": "boxzoom"}], "id": "el4894140349038975688", "width": 1152.0, "axes": [{"sharex": [], "xlim": [733972.0, 736608.0], "lines": [{"linewidth": 1.75, "yindex": 1, "id": "el4894140349003490248", "color": "#4C72B0", "zorder": 2, "xindex": 0, "drawstyle": "default", "coordinates": "data", "alpha": 1, "dasharray": "none", "data": "data01"}, {"linewidth": 1.75, "yindex": 2, "id": "el4894140349037543552", "color": "#55A868", "zorder": 2, "xindex": 0, "drawstyle": "default", "coordinates": "data", "alpha": 1, "dasharray": "none", "data": "data01"}, {"linewidth": 1.75, "yindex": 3, "id": "el4894140349003378360", "color": "#C44E52", "zorder": 2, "xindex": 0, "drawstyle": "default", "coordinates": "data", "alpha": 1, "dasharray": "none", "data": "data01"}, {"linewidth": 1.75, "yindex": 4, "id": "el4894140349003377968", "color": "#8172B2", "zorder": 2, "xindex": 0, "drawstyle": "default", "coordinates": "data", "alpha": 1, "dasharray": "none", "data": "data01"}, {"linewidth": 1.75, "yindex": 4, "id": "el4894140349004731840", "color": "#CCB974", "zorder": 2, "xindex": 0, "drawstyle": "default", "coordinates": "data", "alpha": 1, "dasharray": "none", "data": "data01"}, {"linewidth": 1.75, "yindex": 5, "id": "el4894140349004428680", "color": "#64B5CD", "zorder": 2, "xindex": 0, "drawstyle": "default", "coordinates": "data", "alpha": 1, "dasharray": "none", "data": "data01"}, {"linewidth": 1.75, "yindex": 1, "id": "el4894140349004035520", "color": "#4C72B0", "zorder": 1000002.0, "xindex": 0, "drawstyle": "default", "coordinates": "axes", "alpha": 1, "dasharray": "none", "data": "data02"}, {"linewidth": 1.75, "yindex": 2, "id": "el4894140349004246992", "color": "#55A868", "zorder": 1000002.0, "xindex": 0, "drawstyle": "default", "coordinates": "axes", "alpha": 1, "dasharray": "none", "data": "data02"}, {"linewidth": 1.75, "yindex": 3, "id": "el4894140349003450688", "color": "#C44E52", "zorder": 1000002.0, "xindex": 0, "drawstyle": "default", "coordinates": "axes", "alpha": 1, "dasharray": "none", "data": "data02"}, {"linewidth": 1.75, "yindex": 4, "id": "el4894140349037063584", "color": "#8172B2", "zorder": 1000002.0, "xindex": 0, "drawstyle": "default", "coordinates": "axes", "alpha": 1, "dasharray": "none", "data": "data02"}, {"linewidth": 1.75, "yindex": 5, "id": "el4894140349005014688", "color": "#CCB974", "zorder": 1000002.0, "xindex": 0, "drawstyle": "default", "coordinates": "axes", "alpha": 1, "dasharray": "none", "data": "data02"}, {"linewidth": 1.75, "yindex": 6, "id": "el4894140349003426056", "color": "#64B5CD", "zorder": 1000002.0, "xindex": 0, "drawstyle": "default", "coordinates": "axes", "alpha": 1, "dasharray": "none", "data": "data02"}], "axesbg": "#EAEAF2", "ylim": [0.03540890204072318, 24.405956984302232], "axesbgalpha": null, "markers": [], "paths": [{"yindex": 1, "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "zorder": 1000000.0, "coordinates": "axes", "alpha": 0.8, "dasharray": "none", "id": "el4894140349004034400", "edgecolor": "#CCCCCC", "edgewidth": 0.3, "facecolor": "#EAEAF2", "xindex": 0, "data": "data03"}], "ydomain": [0.03540890204072318, 24.405956984302232], "collections": [], "xdomain": [[2010, 6, 19, 0, 0, 0, 0.0], [2017, 9, 6, 0, 0, 0, 0.0]], "sharey": [], "images": [], "zoomable": true, "texts": [{"fontsize": 11.0, "color": "#262626", "text": "date", "rotation": -0.0, "coordinates": "axes", "alpha": 1, "id": "el4894140349037505000", "position": [0.5, -0.1052228146713112], "zorder": 3, "v_baseline": "hanging", "h_anchor": "middle"}, {"fontsize": 10.0, "color": "#262626", "text": "tsla_open", "rotation": -0.0, "coordinates": "axes", "alpha": 1, "id": "el4894140349004036920", "position": [0.9187948028673836, 0.292755991285403], "zorder": 1000003.0, "v_baseline": "auto", "h_anchor": "start"}, {"f ...

# %%
# Just in case you want to build an interactive dashboard for Elon Musk:
with open('../shared-resources/musk.html', 'w') as fout:
    fout.write(mpld3.fig_to_html(ax.figure))

# %% [markdown]
# Here's a [link to that dashboard](../shared-resources/musk.html)
#
# ## Your Turn
#
# 1. plot all the closing prices for these stocks
# 2. create an interactive D3 plot from the figure
# 3. save the interactactive D3 plot to HTML on your computer
# 4. interact with your HTML file!
#
# ## BONUS
#
# 1. Look at my TSLA plot closely (zoom in)
# 2. What's wrong with the close, open, high, and low prices?
# 3. Can you normalize the data better than I did so this doesn't happen?
