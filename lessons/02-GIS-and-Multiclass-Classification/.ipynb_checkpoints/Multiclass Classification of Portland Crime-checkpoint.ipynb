# %% [markdown]
# # [Multiclass Classification](http://scikit-learn.org/stable/modules/multiclass.html#multiclass)
#
# ## Review
#
# You've done...
#
# #### Regression
#
# * Linear regression to predict weight from height
# * **Multivariate** linear regresion to predict weight from height and gender
#
# #### Binary Classification
#
# If our data set contains only 2 genders, we have a binary classification problem.
#
# * Logistic regression to predict gender (*categorical*) from height (*univariate continuous*)
# * Logistic regression to predict gender (*categorical*) from height and weight (*multivariate continuous*)
#
# ## Today
#
# What do we do with are real-world data set with more than 2 genders?
# Or more than 2 colors?
# Or more than 2 types of endangered species?
# Or more than categories/classes of any type?
#
# Today you're going to do...
#
# #### Multiclass Classification
#
# * Predict crime (*multiclass*) from latitude (*univariate*)
# * Predict crime (*multiclass*) from lat, lon, date, time, neighborhood (*multivariate*)
#
# When we want to predict something that isn't just one class or another (binary), but has more than one category or class, we call that **Multiclass Classification**

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
# df = pd.read_csv('https://raw.githubusercontent.com/hackoregon/hack-university-database-engineering/master/Data/Crime%20Data/crimedata.csv')
# del df['record_id']
# df.to_csv('../shared-resources/portland_crime.csv')
df = pd.read_csv('../shared-resources/portland_crime.csv', index_col=0, header=0)

# %%
df.head(3)
# Out:
#    report_date report_time major_offense_type  \
# id
# 10  2014-01-06    09:25:00       Sex Offenses
# 11  2014-01-05    17:53:00        Liquor Laws
# 12  2014-01-23    22:15:00           Burglary
#
#                                              address    neighborhood  \
# id
# 10                             Unknown/Not Available  SOUTH PORTLAND
# 11   SW ALDER ST and SW 10TH AVE, PORTLAND, OR 97205        DOWNTOWN
# 12  251-399 block of NE 80TH AVE, PORTLAND, OR 97213      MONTAVILLA
#
#      police_precinct police_district   xcoordinate   ycoordinate
# id
# 10  PORTLAND PREC CE             890           NaN           NaN
# 11  PORTLAND PREC CE             842  7.642970e+06  683475.64534
# 12  PORTLAND PREC EA             902  7.668701e+06  684231.79199

# %%
df.describe()
# Out:
#         xcoordinate    ycoordinate
# count  5.396300e+04   53963.000000
# mean   7.655826e+06  684865.814018
# std    1.611395e+04   11582.723344
# min    7.568600e+06  588728.800520
# 25%    7.643957e+06  678147.698490
# 50%    7.650161e+06  684086.216210
# 75%    7.669203e+06  689327.735240
# max    7.717426e+06  726347.339900

# %%
df.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc97a03d780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc979fe3208>]], dtype=object)

# %% [markdown]
# So we only have 3 numerical features to work with?
# And one of them is useless (**id**)!
#
# #### **NOTE:** IDs are not always useless.
#
# One Kaggle competition was won by a machine that figured out that the ID contained the answer!
# IDs often contain information about when the records were inserted into the DB.

# %% [markdown]
# ## Datetimes (Pandas **Timestamp**)
#
# There are lots of [numerical features](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#time-date-components) we can extract from datetimes (Timestamp) objects
#
# * year
# * month
# * day of month
# * day of year
# * day of week
# * is it a holiday
# * is it a weekday
#
# ...

# %%
pd.to_datetime(df.report_date).describe()
# Out:
# count                   61497
# unique                    365
# top       2014-01-01 00:00:00
# freq                      299
# first     2014-01-01 00:00:00
# last      2014-12-31 00:00:00
# Name: report_date, dtype: object

# %%
df['report_date'] = pd.to_datetime(df.report_date + ' ' + df.report_time)
df.head(3)
# Out:
#            report_date report_time major_offense_type  \
# id
# 10 2014-01-06 09:25:00    09:25:00       Sex Offenses
# 11 2014-01-05 17:53:00    17:53:00        Liquor Laws
# 12 2014-01-23 22:15:00    22:15:00           Burglary
#
#                                              address    neighborhood  \
# id
# 10                             Unknown/Not Available  SOUTH PORTLAND
# 11   SW ALDER ST and SW 10TH AVE, PORTLAND, OR 97205        DOWNTOWN
# 12  251-399 block of NE 80TH AVE, PORTLAND, OR 97213      MONTAVILLA
#
#      police_precinct police_district   xcoordinate   ycoordinate
# id
# 10  PORTLAND PREC CE             890           NaN           NaN
# 11  PORTLAND PREC CE             842  7.642970e+06  683475.64534
# 12  PORTLAND PREC EA             902  7.668701e+06  684231.79199

# %% [markdown]
# ## What about categories like neighborhood?
#
# `pd.get_dummies` can convert any categorical variable to separate binary class variables, one in each column.
# `pd.concat` can combine multiple tables into one
#
#
# So let's add the neighborhood
#
# **NOTE:** Only do this for *categorical* variables, **not** *ordinals*

# %%
neighborhood = pd.get_dummies(df['neighborhood'])
neighborhood.head(3)
# Out:
#     ALAMEDA  ARBOR LODGE  ARDENWALD  ARGAY  ARLINGTON HGHTS  ARNOLD CREEK  \
# id
# 10        0            0          0      0                0             0
# 11        0            0          0      0                0             0
# 12        0            0          0      0                0             0
#
#     ASHCREEK  BEAUMONT-WILSHR  BEAVERTON - FIVE OAKS 3C  BOISE  ...    \
# id                                                              ...
# 10         0                0                         0      0  ...
# 11         0                0                         0      0  ...
# 12         0                0                         0      0  ...
#
#     TUALATIN - TU3  UNIVERSITY PARK  VERNON  W PORTLAND PARK  WEST BEAVERTON  \
# id
# 10               0                0       0                0               0
# 11               0                0       0                0               0
# 12               0                0       0                0               0
#
#     WILKES  WOODLAND PARK  WOODLAWN  WOODSTOCK  WSLOT
# id
# 10       0              0         0          0      0
# 11       0              0         0          0      0
# 12       0              0         0          0      0
#
# [3 rows x 117 columns]

# %%
df = pd.concat([df, neighborhood], axis=1)

# %%
df.describe()
# Out:
#         xcoordinate    ycoordinate       ALAMEDA   ARBOR LODGE     ARDENWALD  \
# count  5.396300e+04   53963.000000  61497.000000  61497.000000  61497.000000
# mean   7.655826e+06  684865.814018      0.002358      0.010131      0.000260
# std    1.611395e+04   11582.723344      0.048501      0.100140      0.016128
# min    7.568600e+06  588728.800520      0.000000      0.000000      0.000000
# 25%    7.643957e+06  678147.698490      0.000000      0.000000      0.000000
# 50%    7.650161e+06  684086.216210      0.000000      0.000000      0.000000
# 75%    7.669203e+06  689327.735240      0.000000      0.000000      0.000000
# max    7.717426e+06  726347.339900      1.000000      1.000000      1.000000
#
#               ARGAY  ARLINGTON HGHTS  ARNOLD CREEK      ASHCREEK  \
# count  61497.000000     61497.000000  61497.000000  61497.000000
# mean       0.008992         0.002683      0.000553      0.001691
# std        0.094401         0.051729      0.023507      0.041089
# min        0.000000         0.000000      0.000000      0.000000
# 25%        0.000000         0.000000      0.000000      0.000000
# 50%        0.000000         0.000000      0.000000      0.000000
# 75%        0.000000         0.000000      0.000000      0.000000
# max        1.000000         1.000000      1.000000      1.000000
#
#        BEAUMONT-WILSHR      ...       TUALATIN - TU3  UNIVERSITY PARK  \
# count     61497.000000      ...         61497.000000     61497.000000
# mean          0.002976      ...             0.000016         0.005512
# std           0.054470      ...             0.004032         0.074042
# min           0.000000      ...             0.000000         0.000000
# 25%           0.000000      ...             0.000000         0.000000
# 50%           0.000000      ...             0.000000         0.000000
# 75%           0.000000      ...             0.000000         0.000000
# max           1.000000      ...             1.000000         1.000000
#
#              VERNON  W PORTLAND PARK  WEST BEAVERTON        WILKES  \
# count  61497.000000     61497.000000    61497.000000  61497.000000
# mean       0.003041         0.002293        0.000016      0.008033
# std        0.055060         0.047829        0.004032      0.089267
# min        0.000000         0.000000        0.000000      0.000000
# 25%        0.000000         0.000000        0.000000      0.000000
# 50%        0.000000         0.000000        0.000000      0.000000
# 75%        0.000000         0.000000        0.000000      0.000000
# max        1.000000         1.000000        1.000000      1.000000
#
#        WOODLAND PARK      WOODLAWN     WOODSTOCK         WSLOT
# count   61497.000000  61497.000000  61497.000000  61497.000000
# mean        0.000407      0.005675      0.009757      0.000033
# std         0.020159      0.075120      0.098293      0.005703
# min         0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      0.000000      0.000000      0.000000
# 50%         0.000000      0.000000      0.000000      0.000000
# 75%         0.000000      0.000000      0.000000      0.000000
# max         1.000000      1.000000      1.000000      1.000000
#
# [8 rows x 119 columns]

# %%
df_crime = pd.get_dummies(df.major_offense_type)
df_crime.describe()
# Out:
#        Aggravated Assault         Arson  Assault, Simple      Burglary  \
# count        61497.000000  61497.000000     61497.000000  61497.000000
# mean             0.027627      0.002374         0.063987      0.066702
# std              0.163904      0.048667         0.244732      0.249508
# min              0.000000      0.000000         0.000000      0.000000
# 25%              0.000000      0.000000         0.000000      0.000000
# 50%              0.000000      0.000000         0.000000      0.000000
# 75%              0.000000      0.000000         0.000000      0.000000
# max              1.000000      1.000000         1.000000      1.000000
#
#              Curfew          DUII  Disorderly Conduct         Drugs  \
# count  61497.000000  61497.000000        61497.000000  61497.000000
# mean       0.000390      0.024115            0.065174      0.043384
# std        0.019751      0.153407            0.246834      0.203722
# min        0.000000      0.000000            0.000000      0.000000
# 25%        0.000000      0.000000            0.000000      0.000000
# 50%        0.000000      0.000000            0.000000      0.000000
# 75%        0.000000      0.000000            0.000000      0.000000
# max        1.000000      1.000000            1.000000      1.000000
#
#        Embezzlement       Forgery      ...       Offenses Against Family  \
# count  61497.000000  61497.000000      ...                  61497.000000
# mean       0.002049      0.009399      ...                      0.000748
# std        0.045219      0.096492      ...                      0.027340
# min        0.000000      0.000000      ...                      0.000000
# 25%        0.000000      0.000000      ...                      0.000000
# 50%        0.000000      0.000000      ...                      0.000000
# 75%        0.000000      0.000000      ...                      0.000000
# max        1.000000      1.000000      ...                      1.000000
#
#        Prostitution          Rape       Robbery       Runaway  Sex Offenses  \
# count  61497.000000  61497.000000  61497.000000  61497.000000  61497.000000
# mean       0.002390      0.003350      0.013757      0.023351      0.007789
# std        0.048833      0.057781      0.116481      0.151016      0.087912
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        Stolen Property      Trespass     Vandalism       Weapons
# count     61497.000000  61497.000000  61497.000000  61497.000000
# mean          0.001171      0.045612      0.071727      0.005350
# std           0.034197      0.208644      0.258038      0.072947
# min           0.000000      0.000000      0.000000      0.000000
# 25%           0.000000      0.000000      0.000000      0.000000
# 50%           0.000000      0.000000      0.000000      0.000000
# 75%           0.000000      0.000000      0.000000      0.000000
# max           1.000000      1.000000      1.000000      1.000000
#
# [8 rows x 27 columns]

# %%
# another way to convert a class into a number
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df.major_offense_type)
df['major_offense_type_int'] = le.transform(df.major_offense_type)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
df = df.dropna(how='any').copy()
X = df[['xcoordinate', 'ycoordinate'] + list(neighborhood.columns)]
y = df['major_offense_type_int']
lr = lr.fit(X, y)
lr.score(X, y)
# Out:
# 0.43611497799014259

# %%
df['predicted_major_offense_type'] = le.inverse_transform(lr.predict(X))
df.head()
# Out:
#            report_date report_time  major_offense_type  \
# id
# 11 2014-01-05 17:53:00    17:53:00         Liquor Laws
# 12 2014-01-23 22:15:00    22:15:00            Burglary
# 13 2014-01-14 16:27:00    16:27:00             Weapons
# 14 2014-01-19 17:51:00    17:51:00            Trespass
# 15 2014-01-08 11:00:00    11:00:00  Disorderly Conduct
#
#                                               address     neighborhood  \
# id
# 11    SW ALDER ST and SW 10TH AVE, PORTLAND, OR 97205         DOWNTOWN
# 12   251-399 block of NE 80TH AVE, PORTLAND, OR 97213       MONTAVILLA
# 13  SW MORRISON ST and SW 6TH AVE, PORTLAND, OR 97204         DOWNTOWN
# 14  5201-5299 block of NE 91ST AVE, PORTLAND, OR 9...           SUMNER
# 15  3300-3498 block of SE 26TH AVE, PORTLAND, OR 9...  HOSFRD-ABRNETHY
#
#      police_precinct police_district   xcoordinate   ycoordinate  ALAMEDA  \
# id
# 11  PORTLAND PREC CE             842  7.642970e+06  683475.64534        0
# 12  PORTLAND PREC EA             902  7.668701e+06  684231.79199        0
# 13  PORTLAND PREC CE             830  7.643759e+06  682869.68110        0
# 14  PORTLAND PREC NO             642  7.672251e+06  697446.17126        0
# 15  PORTLAND PREC CE             730  7.653553e+06  675335.70768        0
#
#                 ...               VERNON  W PORTLAND PARK  WEST BEAVERTON  \
# id              ...
# 11              ...                    0                0               0
# 12              ...                    0                0               0
# 13              ...                    0                0               0
# 14              ...                    0                0               0
# 15              ...                    0                0               0
#
#     WILKES  WOODLAND PARK  WOODLAWN  WOODSTOCK  WSLOT  major_offense_type_int  \
# id
# 11       0              0         0          0      0                      15
# 12       0              0         0          0      0                       3
# 13       0              0         0          0      0                      26
# 14       0              0         0          0      0                      24
# 15       0              0         0          0      0                       6
#
#     predicted_major_offense_type
# id
# 11                       Larceny
# 12                       Larceny
# 13                       Larceny
# 14                       Larceny
# 15                       Larceny
#
# [5 rows x 128 columns]

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(class_weight='balanced', solver='lbfgs', multi_class='multinomial')
lr = lr.fit(X, y)  # .values[:,1].reshape(-1,1))
lr.score(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-808094ff8c66> in <module>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 lr = LogisticRegression(class_weight='balanced', solver='lbfgs', multi_class='multinomial')
# ----> 3 y = df2.major_offense_type.values.reshape(-1, 1)
#       4 print(y.shape)
#       5 lr = lr.fit(X, y)  # .values[:,1].reshape(-1,1))
#
# NameError: name 'df2' is not defined

# %%
df = pd.read_csv('../shared-resources/portland_crime.csv', index_col='id', header=0)
del df['Unnamed: 0']

# %%
df.to_csv('../shared-resources/portland_crime.csv')
print(df.columns[4])
df[df.columns[4]]
# Out:
# neighborhood
# id
# 10        SOUTH PORTLAND
# 11              DOWNTOWN
# 12            MONTAVILLA
# 13              DOWNTOWN
# 14                SUMNER
# 15       HOSFRD-ABRNETHY
# 16            MONTAVILLA
# 17              DOWNTOWN
# 18       SELLWD-MORELAND
# 19              DOWNTOWN
# 20              DOWNTOWN
# 21        SOUTH PORTLAND
# 22       HOSFRD-ABRNETHY
# 23       SELLWD-MORELAND
# 24              DOWNTOWN
# 25              DOWNTOWN
# 26              DOWNTOWN
# 27       SELLWD-MORELAND
# 28              DOWNTOWN
# 29              DOWNTOWN
# 30       HOSFRD-ABRNETHY
# 31            MONTAVILLA
# 32              DOWNTOWN
# 33              DOWNTOWN
# 34       HOSFRD-ABRNETHY
# 35              DOWNTOWN
# 36              DOWNTOWN
# 37              DOWNTOWN
# 38            MONTAVILLA
# 39              DOWNTOWN
#               ...
# 61477             VERNON
# 61478          NORTHWEST
# 61479             WILKES
# 61480           HUMBOLDT
# 61481             WILKES
# 61482          NORTHWEST
# 61483    ARLINGTON HGHTS
# 61484          NORTHWEST
# 61485          NORTHWEST
# 61486           HUMBOLDT
# 61487          NORTHWEST
# 61488             WILKES
# 61489          NORTHWEST
# 61490             WILKES
# 61491             WILKES
# 61492             WILKES
# 61493             WILKES
# 61494          NORTHWEST
# 61495             WILKES
# 61496          NORTHWEST
# 61497          HOLLYWOOD
# 61498             WILKES
# 61499          NORTHWEST
# 61500          NORTHWEST
# 61501          NORTHWEST
# 61502          NORTHWEST
# 61503    SULLIVANS GULCH
# 61504          NORTHWEST
# 61505    ARLINGTON HGHTS
# 61506             WILKES
# Name: neighborhood, Length: 61497, dtype: object

# %%
df['report_date'][10]
# Out:
# '2014-01-06'
